# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint


Population2000_csv = "Resources/countyPopEst2000_2010_CLEAN.csv"

Population2010_csv = "Resources/countyPop2010_2016_CLEAN.csv"

# %%
Population2000= pd.read_csv(Population2000_csv)

Population2010= pd.read_csv(Population2010_csv)

# %%
Population2000
Population2000['Location'] = (Population2010.State +", " +Population2010.County)

# %%
Population2000
# Out:
#         State             County    2000    2001    2002    2003    2004  \
# 0     Alabama     Autauga County   44021   44889   45909   46800   48366
# 1     Alabama     Baldwin County  141342  144875  147957  151509  156266
# 2     Alabama     Barbour County   29015   28863   28653   28594   28287
# 3     Alabama        Bibb County   19913   21028   21199   21399   21721
# 4     Alabama      Blount County   51107   51845   52551   53457   54124
# ...       ...                ...     ...     ...     ...     ...     ...
# 3139  Wyoming  Sweetwater County   37552   36899   37428   37450   38026
# 3140  Wyoming       Teton County   18381   18653   18837   19066   19467
# 3141  Wyoming       Uinta County   19666   19413   19587   19480   19470
# 3142  Wyoming    Washakie County    8252    8068    7988    7976    7960
# 3143  Wyoming      Weston County    6627    6487    6578    6610    6646
#
#         2005    2006    2007    2008    2009                   Location
# 0      49676   51328   52405   53277   54135    Alabama, Autauga County
# 1     162183  168121  172404  175827  179406    Alabama, Baldwin County
# 2      28027   27861   27757   27808   27657    Alabama, Barbour County
# 3      22042   22099   22438   22705   22941       Alabama, Bibb County
# 4      54624   55485   56240   57055   57341     Alabama, Blount County
# ...      ...     ...     ...     ...     ...                        ...
# 3139   38739   39749   41470   42358   44133   Wyoming, Washakie County
# 3140   19632   20014   20472   20988   21232     Wyoming, Weston County
# 3141   19494   19709   20171   20613   21054                        NaN
# 3142    8022    7979    8169    8229    8423                        NaN
# 3143    6594    6717    7033    7133    7266                        NaN
#
# [3144 rows x 13 columns]

# %%
Population2010['Location'] = (Population2010.State +", " +Population2010.County)

Population2010
# Out:
#                  County     State     2010     2011     2012     2013  \
# 0        Autauga County   Alabama   54,773   55,227   54,954   54,727
# 1        Baldwin County   Alabama  183,112  186,558  190,145  194,885
# 2        Barbour County   Alabama   27,327   27,341   27,169   26,937
# 3           Bibb County   Alabama   22,870   22,745   22,667   22,521
# 4         Blount County   Alabama   57,376   57,560   57,580   57,619
# ...                 ...       ...      ...      ...      ...      ...
# 3136  Sweetwater County   Wyoming   43,574   43,986   45,002   45,157
# 3137       Teton County   Wyoming   21,296   21,414   21,624   22,315
# 3138       Uinta County   Wyoming   21,089   20,896   20,996   20,951
# 3139    Washakie County   Wyoming    8,530    8,449    8,409    8,413
# 3140      Weston County   Wyoming    7,198    7,142    7,077    7,136
#
#          2014     2015     2016                     Location
# 0      54,893   54,864   55,243      Alabama, Autauga County
# 1     199,183  202,939  207,601      Alabama, Baldwin County
# 2      26,755   26,283   25,806      Alabama, Barbour County
# 3      22,553   22,566   22,586         Alabama, Bibb County
# 4      57,526   57,526   57,494       Alabama, Blount County
# ...       ...      ...      ...                          ...
# 3136   44,948   44,719   44,222   Wyoming, Sweetwater County
# 3137   22,773   23,047   23,234        Wyoming, Teton County
# 3138   20,822   20,763   20,682        Wyoming, Uinta County
# 3139    8,273    8,278    8,165     Wyoming, Washakie County
# 3140    7,138    7,208    7,220       Wyoming, Weston County
#
# [3141 rows x 10 columns]

# %%
Population2010_loc = Population2010[['Location', 'County',
 'State',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]
Population2010_loc
# Out:
#                          Location             County     State     2010  \
# 0         Alabama, Autauga County     Autauga County   Alabama   54,773
# 1         Alabama, Baldwin County     Baldwin County   Alabama  183,112
# 2         Alabama, Barbour County     Barbour County   Alabama   27,327
# 3            Alabama, Bibb County        Bibb County   Alabama   22,870
# 4          Alabama, Blount County      Blount County   Alabama   57,376
# ...                           ...                ...       ...      ...
# 3136   Wyoming, Sweetwater County  Sweetwater County   Wyoming   43,574
# 3137        Wyoming, Teton County       Teton County   Wyoming   21,296
# 3138        Wyoming, Uinta County       Uinta County   Wyoming   21,089
# 3139     Wyoming, Washakie County    Washakie County   Wyoming    8,530
# 3140       Wyoming, Weston County      Weston County   Wyoming    7,198
#
#          2011     2012     2013     2014     2015     2016
# 0      55,227   54,954   54,727   54,893   54,864   55,243
# 1     186,558  190,145  194,885  199,183  202,939  207,601
# 2      27,341   27,169   26,937   26,755   26,283   25,806
# 3      22,745   22,667   22,521   22,553   22,566   22,586
# 4      57,560   57,580   57,619   57,526   57,526   57,494
# ...       ...      ...      ...      ...      ...      ...
# 3136   43,986   45,002   45,157   44,948   44,719   44,222
# 3137   21,414   21,624   22,315   22,773   23,047   23,234
# 3138   20,896   20,996   20,951   20,822   20,763   20,682
# 3139    8,449    8,409    8,413    8,273    8,278    8,165
# 3140    7,142    7,077    7,136    7,138    7,208    7,220
#
# [3141 rows x 10 columns]

# %%
#cols = list(Population2000.columns.values)
#cols
Population2000_loc = Population2000[['Location', 'State',
 'County',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009']]
Population2000_loc
# Out:
#                        Location    State             County    2000    2001  \
# 0       Alabama, Autauga County  Alabama     Autauga County   44021   44889
# 1       Alabama, Baldwin County  Alabama     Baldwin County  141342  144875
# 2       Alabama, Barbour County  Alabama     Barbour County   29015   28863
# 3          Alabama, Bibb County  Alabama        Bibb County   19913   21028
# 4        Alabama, Blount County  Alabama      Blount County   51107   51845
# ...                         ...      ...                ...     ...     ...
# 3139   Wyoming, Washakie County  Wyoming  Sweetwater County   37552   36899
# 3140     Wyoming, Weston County  Wyoming       Teton County   18381   18653
# 3141                        NaN  Wyoming       Uinta County   19666   19413
# 3142                        NaN  Wyoming    Washakie County    8252    8068
# 3143                        NaN  Wyoming      Weston County    6627    6487
#
#         2002    2003    2004    2005    2006    2007    2008    2009
# 0      45909   46800   48366   49676   51328   52405   53277   54135
# 1     147957  151509  156266  162183  168121  172404  175827  179406
# 2      28653   28594   28287   28027   27861   27757   27808   27657
# 3      21199   21399   21721   22042   22099   22438   22705   22941
# 4      52551   53457   54124   54624   55485   56240   57055   57341
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 3139   37428   37450   38026   38739   39749   41470   42358   44133
# 3140   18837   19066   19467   19632   20014   20472   20988   21232
# 3141   19587   19480   19470   19494   19709   20171   20613   21054
# 3142    7988    7976    7960    8022    7979    8169    8229    8423
# 3143    6578    6610    6646    6594    6717    7033    7133    7266
#
# [3144 rows x 13 columns]

# %%
Population2000.merge(Population2010, left_on='Location', right_on='Location', how='left')

#result = pd.concat([Population2010_loc, Population2000_loc], axis=1, sort=False)
#result

#result2 = pd.concat([Population2000_loc, Population2010_loc], axis=1, sort=False)
#result2
# Out:
#       State_x           County_x    2000    2001    2002    2003    2004  \
# 0     Alabama     Autauga County   44021   44889   45909   46800   48366
# 1     Alabama     Baldwin County  141342  144875  147957  151509  156266
# 2     Alabama     Barbour County   29015   28863   28653   28594   28287
# 3     Alabama        Bibb County   19913   21028   21199   21399   21721
# 4     Alabama      Blount County   51107   51845   52551   53457   54124
# ...       ...                ...     ...     ...     ...     ...     ...
# 3155  Wyoming  Sweetwater County   37552   36899   37428   37450   38026
# 3156  Wyoming       Teton County   18381   18653   18837   19066   19467
# 3157  Wyoming       Uinta County   19666   19413   19587   19480   19470
# 3158  Wyoming    Washakie County    8252    8068    7988    7976    7960
# 3159  Wyoming      Weston County    6627    6487    6578    6610    6646
#
#         2005    2006    2007  ...                   Location         County_y  \
# 0      49676   51328   52405  ...    Alabama, Autauga County   Autauga County
# 1     162183  168121  172404  ...    Alabama, Baldwin County   Baldwin County
# 2      28027   27861   27757  ...    Alabama, Barbour County   Barbour County
# 3      22042   22099   22438  ...       Alabama, Bibb County      Bibb County
# 4      54624   55485   56240  ...     Alabama, Blount County    Blount County
# ...      ...     ...     ...  ...                        ...              ...
# 3155   38739   39749   41470  ...   Wyoming, Washakie County  Washakie County
# 3156   19632   20014   20472  ...     Wyoming, Weston County    Weston County
# 3157   19494   19709   20171  ...                        NaN              NaN
# 3158    8022    7979    8169  ...                        NaN              NaN
# 3159    6594    6717    7033  ...                        NaN              NaN
#
#        State_y     2010     2011     2012     2013     2014     2015     2016
# 0      Alabama   54,773   55,227   54,954   54,727   54,893   54,864   55,243
# 1      Alabama  183,112  186,558  190,145  194,885  199,183  202,939  207,601
# 2      Alabama   27,327   27,341   27,169   26,937   26,755   26,283   25,806
# 3      Alabama   22,870   22,745   22,667   22,521   22,553   22,566   22,586
# 4      Alabama   57,376   57,560   57,580   57,619   57,526   57,526   57,494
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 3155   Wyoming    8,530    8,449    8,409    8,413    8,273    8,278    8,165
# 3156   Wyoming    7,198    7,142    7,077    7,136    7,138    7,208    7,220
# 3157       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3158       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3159       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [3160 rows x 22 columns]

# %%
location_2000 = Population2000['Location'].to_list()
location_2010 = Population2010['Location'].to_list()

# %%
location_2000_2010 = location_2000 + location_2010

# %%
location_list = pd.DataFrame(location_2000_2010, columns = ['county_state'])

# %%
location_list
# Out:
#                      county_state
# 0         Alabama, Autauga County
# 1         Alabama, Baldwin County
# 2         Alabama, Barbour County
# 3            Alabama, Bibb County
# 4          Alabama, Blount County
# ...                           ...
# 6280   Wyoming, Sweetwater County
# 6281        Wyoming, Teton County
# 6282        Wyoming, Uinta County
# 6283     Wyoming, Washakie County
# 6284       Wyoming, Weston County
#
# [6285 rows x 1 columns]
