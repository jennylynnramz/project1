# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint


Population2000_csv = "Resources/countyPopEst2000_2010_CLEAN.csv"

Population2010_csv = "Resources/countyPop2010_2016_CLEAN.csv"

# %%
Population2000= pd.read_csv(Population2000_csv)

Population2010= pd.read_csv(Population2010_csv)

# %%
Population2000
Population2000['Location'] = (Population2000.State +", " +Population2000.County)

# %%
Population2000
# Out:
#         State      County    2000    2001    2002    2003    2004    2005  \
# 0     Alabama     Autauga   44021   44889   45909   46800   48366   49676
# 1     Alabama     Baldwin  141342  144875  147957  151509  156266  162183
# 2     Alabama     Barbour   29015   28863   28653   28594   28287   28027
# 3     Alabama        Bibb   19913   21028   21199   21399   21721   22042
# 4     Alabama      Blount   51107   51845   52551   53457   54124   54624
# ...       ...         ...     ...     ...     ...     ...     ...     ...
# 3139  Wyoming  Sweetwater   37552   36899   37428   37450   38026   38739
# 3140  Wyoming       Teton   18381   18653   18837   19066   19467   19632
# 3141  Wyoming       Uinta   19666   19413   19587   19480   19470   19494
# 3142  Wyoming    Washakie    8252    8068    7988    7976    7960    8022
# 3143  Wyoming      Weston    6627    6487    6578    6610    6646    6594
#
#         2006    2007    2008    2009             Location
# ...

# %%
Population2010['Location'] = (Population2010.State +", " +Population2010.County)

Population2010
# Out:
#           County    State     2010     2011     2012     2013     2014  \
# 0        Autauga  Alabama   54,773   55,227   54,954   54,727   54,893
# 1        Baldwin  Alabama  183,112  186,558  190,145  194,885  199,183
# 2        Barbour  Alabama   27,327   27,341   27,169   26,937   26,755
# 3           Bibb  Alabama   22,870   22,745   22,667   22,521   22,553
# 4         Blount  Alabama   57,376   57,560   57,580   57,619   57,526
# ...          ...      ...      ...      ...      ...      ...      ...
# 3136  Sweetwater  Wyoming   43,574   43,986   45,002   45,157   44,948
# 3137       Teton  Wyoming   21,296   21,414   21,624   22,315   22,773
# 3138       Uinta  Wyoming   21,089   20,896   20,996   20,951   20,822
# 3139    Washakie  Wyoming    8,530    8,449    8,409    8,413    8,273
# 3140      Weston  Wyoming    7,198    7,142    7,077    7,136    7,138
#
#          2015     2016             Location
# 0      54,864   55,243     Alabama, Autauga
# ...

# %%
Population2010_loc = Population2010[['Location', 'County',
 'State',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]
Population2010_loc
# Out:
#                  Location      County    State     2010     2011     2012  \
# 0        Alabama, Autauga     Autauga  Alabama   54,773   55,227   54,954
# 1        Alabama, Baldwin     Baldwin  Alabama  183,112  186,558  190,145
# 2        Alabama, Barbour     Barbour  Alabama   27,327   27,341   27,169
# 3           Alabama, Bibb        Bibb  Alabama   22,870   22,745   22,667
# 4         Alabama, Blount      Blount  Alabama   57,376   57,560   57,580
# ...                   ...         ...      ...      ...      ...      ...
# 3136  Wyoming, Sweetwater  Sweetwater  Wyoming   43,574   43,986   45,002
# 3137       Wyoming, Teton       Teton  Wyoming   21,296   21,414   21,624
# 3138       Wyoming, Uinta       Uinta  Wyoming   21,089   20,896   20,996
# 3139    Wyoming, Washakie    Washakie  Wyoming    8,530    8,449    8,409
# 3140      Wyoming, Weston      Weston  Wyoming    7,198    7,142    7,077
#
#          2013     2014     2015     2016
# ...

# %%
#cols = list(Population2000.columns.values)
#cols
Population2000_loc = Population2000[['Location', 'State',
 'County',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009']]
Population2000_loc
# Out:
#                  Location    State      County    2000    2001    2002  \
# 0        Alabama, Autauga  Alabama     Autauga   44021   44889   45909
# 1        Alabama, Baldwin  Alabama     Baldwin  141342  144875  147957
# 2        Alabama, Barbour  Alabama     Barbour   29015   28863   28653
# 3           Alabama, Bibb  Alabama        Bibb   19913   21028   21199
# 4         Alabama, Blount  Alabama      Blount   51107   51845   52551
# ...                   ...      ...         ...     ...     ...     ...
# 3139  Wyoming, Sweetwater  Wyoming  Sweetwater   37552   36899   37428
# 3140       Wyoming, Teton  Wyoming       Teton   18381   18653   18837
# 3141       Wyoming, Uinta  Wyoming       Uinta   19666   19413   19587
# 3142    Wyoming, Washakie  Wyoming    Washakie    8252    8068    7988
# 3143      Wyoming, Weston  Wyoming      Weston    6627    6487    6578
#
#         2003    2004    2005    2006    2007    2008    2009
# ...

# %%
County_Population_Merge_2000_2016 = Population2000.merge(Population2010, left_on='Location', right_on='Location', how='left')

#result = pd.concat([Population2010_loc, Population2000_loc], axis=1, sort=False)
#result

#result2 = pd.concat([Population2000_loc, Population2010_loc], axis=1, sort=False)
#result2

# %%
County_Population_Merge_2000_2016
# Out:
#       State_x    County_x    2000    2001    2002    2003    2004    2005  \
# 0     Alabama     Autauga   44021   44889   45909   46800   48366   49676
# 1     Alabama     Baldwin  141342  144875  147957  151509  156266  162183
# 2     Alabama     Barbour   29015   28863   28653   28594   28287   28027
# 3     Alabama        Bibb   19913   21028   21199   21399   21721   22042
# 4     Alabama      Blount   51107   51845   52551   53457   54124   54624
# ...       ...         ...     ...     ...     ...     ...     ...     ...
# 3139  Wyoming  Sweetwater   37552   36899   37428   37450   38026   38739
# 3140  Wyoming       Teton   18381   18653   18837   19066   19467   19632
# 3141  Wyoming       Uinta   19666   19413   19587   19480   19470   19494
# 3142  Wyoming    Washakie    8252    8068    7988    7976    7960    8022
# 3143  Wyoming      Weston    6627    6487    6578    6610    6646    6594
#
#         2006    2007  ...             Location    County_y  State_y     2010  \
# ...

# %%
County_Population_Merge_2000_2016.dropna()
# Out:
#       State_x    County_x    2000    2001    2002    2003    2004    2005  \
# 0     Alabama     Autauga   44021   44889   45909   46800   48366   49676
# 1     Alabama     Baldwin  141342  144875  147957  151509  156266  162183
# 2     Alabama     Barbour   29015   28863   28653   28594   28287   28027
# 3     Alabama        Bibb   19913   21028   21199   21399   21721   22042
# 4     Alabama      Blount   51107   51845   52551   53457   54124   54624
# ...       ...         ...     ...     ...     ...     ...     ...     ...
# 3139  Wyoming  Sweetwater   37552   36899   37428   37450   38026   38739
# 3140  Wyoming       Teton   18381   18653   18837   19066   19467   19632
# 3141  Wyoming       Uinta   19666   19413   19587   19480   19470   19494
# 3142  Wyoming    Washakie    8252    8068    7988    7976    7960    8022
# 3143  Wyoming      Weston    6627    6487    6578    6610    6646    6594
#
#         2006    2007  ...             Location    County_y  State_y     2010  \
# ...

# %%
County_Population_Merge_2000_2016_2 = County_Population_Merge_2000_2016.drop(columns=['County_y','State_y'])

# %%
Population2000_2010_name = County_Population_Merge_2000_2016_2[['State_x',
 'County_x', 'Location',
 '2000',
 '2001',
 '2002',
 '2003',
 '2004',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016']]
Population2000_loc
# Out:
#                  Location    State      County    2000    2001    2002  \
# 0        Alabama, Autauga  Alabama     Autauga   44021   44889   45909
# 1        Alabama, Baldwin  Alabama     Baldwin  141342  144875  147957
# 2        Alabama, Barbour  Alabama     Barbour   29015   28863   28653
# 3           Alabama, Bibb  Alabama        Bibb   19913   21028   21199
# 4         Alabama, Blount  Alabama      Blount   51107   51845   52551
# ...                   ...      ...         ...     ...     ...     ...
# 3139  Wyoming, Sweetwater  Wyoming  Sweetwater   37552   36899   37428
# 3140       Wyoming, Teton  Wyoming       Teton   18381   18653   18837
# 3141       Wyoming, Uinta  Wyoming       Uinta   19666   19413   19587
# 3142    Wyoming, Washakie  Wyoming    Washakie    8252    8068    7988
# 3143      Wyoming, Weston  Wyoming      Weston    6627    6487    6578
#
#         2003    2004    2005    2006    2007    2008    2009
# ...

# %%
Population2000_2010_name2 = Population2000_2010_name.rename(columns={'State_x': 'State', 'County_x':'County'})
Population2000_2010_name2
# Out:
#         State      County             Location    2000    2001    2002  \
# 0     Alabama     Autauga     Alabama, Autauga   44021   44889   45909
# 1     Alabama     Baldwin     Alabama, Baldwin  141342  144875  147957
# 2     Alabama     Barbour     Alabama, Barbour   29015   28863   28653
# 3     Alabama        Bibb        Alabama, Bibb   19913   21028   21199
# 4     Alabama      Blount      Alabama, Blount   51107   51845   52551
# ...       ...         ...                  ...     ...     ...     ...
# 3139  Wyoming  Sweetwater  Wyoming, Sweetwater   37552   36899   37428
# 3140  Wyoming       Teton       Wyoming, Teton   18381   18653   18837
# 3141  Wyoming       Uinta       Wyoming, Uinta   19666   19413   19587
# 3142  Wyoming    Washakie    Wyoming, Washakie    8252    8068    7988
# 3143  Wyoming      Weston      Wyoming, Weston    6627    6487    6578
#
#         2003    2004    2005    2006    2007    2008    2009     2010  \
# ...

# %%
Population2000_2010_name2.to_csv (r'Resources/population2000-2016ALL.csv', index = False, header=True)
