# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint


election_data_all_csv = "Resources/election_all.csv"

# %%
election_data_all= pd.read_csv(election_data_all_csv)
election_data_all
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 3      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50519  2016   Alaska       AK  District 40  2040.0  President
# 50520  2016   Alaska       AK  District 40  2040.0  President
# 50521  2016   Alaska      NaN  District 99  2099.0  President
# 50522  2016   Alaska      NaN  District 99  2099.0  President
# 50523  2016   Alaska      NaN  District 99  2099.0  President
#
#              candidate       party  candidatevotes  totalvotes   version
# 0              Al Gore    democrat          4942.0       17208  20191203
# 1       George W. Bush  republican         11993.0       17208  20191203
# ...

# %%
election_data_all_dropNA = election_data_all.dropna()

# %%
election_data_2004_1 = election_data_all_dropNA[election_data_all_dropNA['year']==2004]
election_data_2004_1
# Out:
#        year    state state_po       county    FIPS     office       candidate  \
# 12464  2004  Alabama       AL      Autauga  1001.0  President      John Kerry
# 12465  2004  Alabama       AL      Autauga  1001.0  President  George W. Bush
# 12467  2004  Alabama       AL      Baldwin  1003.0  President      John Kerry
# 12468  2004  Alabama       AL      Baldwin  1003.0  President  George W. Bush
# 12470  2004  Alabama       AL      Barbour  1005.0  President      John Kerry
# ...     ...      ...      ...          ...     ...        ...             ...
# 50144  2004   Alaska       AK  District 38  2038.0  President  George W. Bush
# 50146  2004   Alaska       AK  District 39  2039.0  President      John Kerry
# 50147  2004   Alaska       AK  District 39  2039.0  President  George W. Bush
# 50149  2004   Alaska       AK  District 40  2040.0  President      John Kerry
# 50150  2004   Alaska       AK  District 40  2040.0  President  George W. Bush
#
# ...

# %%
election_data_2004_2 = election_data_2004_1.drop(columns=['FIPS', 'version', 'office'])
election_data_2004_2
# Out:
#        year    state state_po       county       candidate       party  \
# 12464  2004  Alabama       AL      Autauga      John Kerry    democrat
# 12465  2004  Alabama       AL      Autauga  George W. Bush  republican
# 12467  2004  Alabama       AL      Baldwin      John Kerry    democrat
# 12468  2004  Alabama       AL      Baldwin  George W. Bush  republican
# 12470  2004  Alabama       AL      Barbour      John Kerry    democrat
# ...     ...      ...      ...          ...             ...         ...
# 50144  2004   Alaska       AK  District 38  George W. Bush  republican
# 50146  2004   Alaska       AK  District 39      John Kerry    democrat
# 50147  2004   Alaska       AK  District 39  George W. Bush  republican
# 50149  2004   Alaska       AK  District 40      John Kerry    democrat
# 50150  2004   Alaska       AK  District 40  George W. Bush  republican
#
#        candidatevotes  totalvotes
# 12464          4758.0       20081
# 12465         15196.0       20081
# ...

# %%
election_data_2004_3 = election_data_2004_2.reset_index(drop=True)

# %%
election_data_2004_3.columns=["year", "state", "state_code", "county", "candidate", "party", "candidate_votes", "total_votes"]
election_data_2004_3
# Out:
#       year    state state_code       county       candidate       party  \
# 0     2004  Alabama         AL      Autauga      John Kerry    democrat
# 1     2004  Alabama         AL      Autauga  George W. Bush  republican
# 2     2004  Alabama         AL      Baldwin      John Kerry    democrat
# 3     2004  Alabama         AL      Baldwin  George W. Bush  republican
# 4     2004  Alabama         AL      Barbour      John Kerry    democrat
# ...    ...      ...        ...          ...             ...         ...
# 6303  2004   Alaska         AK  District 38  George W. Bush  republican
# 6304  2004   Alaska         AK  District 39      John Kerry    democrat
# 6305  2004   Alaska         AK  District 39  George W. Bush  republican
# 6306  2004   Alaska         AK  District 40      John Kerry    democrat
# 6307  2004   Alaska         AK  District 40  George W. Bush  republican
#
#       candidate_votes  total_votes
# 0              4758.0        20081
# ...

# %%
election_data_2004_3

election_data_2004_3.to_csv (r'Resources/election_data2004.csv', index = False, header=True)
