# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint


election_data_all_csv = "Resources/election_all.csv"

# %%
election_data_all= pd.read_csv(election_data_all_csv)
election_data_all
# Out:
#        year    state state_po       county    FIPS     office  \
# 0      2000  Alabama       AL      Autauga  1001.0  President
# 1      2000  Alabama       AL      Autauga  1001.0  President
# 2      2000  Alabama       AL      Autauga  1001.0  President
# 3      2000  Alabama       AL      Autauga  1001.0  President
# 4      2000  Alabama       AL      Baldwin  1003.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50519  2016   Alaska       AK  District 40  2040.0  President
# 50520  2016   Alaska       AK  District 40  2040.0  President
# 50521  2016   Alaska      NaN  District 99  2099.0  President
# 50522  2016   Alaska      NaN  District 99  2099.0  President
# 50523  2016   Alaska      NaN  District 99  2099.0  President
#
#              candidate       party  candidatevotes  totalvotes   version
# 0              Al Gore    democrat          4942.0       17208  20191203
# 1       George W. Bush  republican         11993.0       17208  20191203
# ...

# %%
election_data_all_dropNA = election_data_all.dropna()

# %%
election_data_2016_1 = election_data_all_dropNA[election_data_all_dropNA['year']==2016]
election_data_2016_1
# Out:
#        year    state state_po       county    FIPS     office  \
# 40517  2016  Alabama       AL      Autauga  1001.0  President
# 40518  2016  Alabama       AL      Autauga  1001.0  President
# 40520  2016  Alabama       AL      Baldwin  1003.0  President
# 40521  2016  Alabama       AL      Baldwin  1003.0  President
# 40523  2016  Alabama       AL      Barbour  1005.0  President
# ...     ...      ...      ...          ...     ...        ...
# 50513  2016   Alaska       AK  District 38  2038.0  President
# 50515  2016   Alaska       AK  District 39  2039.0  President
# 50516  2016   Alaska       AK  District 39  2039.0  President
# 50518  2016   Alaska       AK  District 40  2040.0  President
# 50519  2016   Alaska       AK  District 40  2040.0  President
#
#              candidate       party  candidatevotes  totalvotes   version
# 40517  Hillary Clinton    democrat          5936.0       24973  20191203
# 40518     Donald Trump  republican         18172.0       24973  20191203
# ...

# %%
election_data_2016_2 = election_data_2016_1.drop(columns=['FIPS', 'version', 'office'])
election_data_2016_2
# Out:
#        year    state state_po       county        candidate       party  \
# 40517  2016  Alabama       AL      Autauga  Hillary Clinton    democrat
# 40518  2016  Alabama       AL      Autauga     Donald Trump  republican
# 40520  2016  Alabama       AL      Baldwin  Hillary Clinton    democrat
# 40521  2016  Alabama       AL      Baldwin     Donald Trump  republican
# 40523  2016  Alabama       AL      Barbour  Hillary Clinton    democrat
# ...     ...      ...      ...          ...              ...         ...
# 50513  2016   Alaska       AK  District 38     Donald Trump  republican
# 50515  2016   Alaska       AK  District 39  Hillary Clinton    democrat
# 50516  2016   Alaska       AK  District 39     Donald Trump  republican
# 50518  2016   Alaska       AK  District 40  Hillary Clinton    democrat
# 50519  2016   Alaska       AK  District 40     Donald Trump  republican
#
#        candidatevotes  totalvotes
# 40517          5936.0       24973
# ...

# %%
election_data_2016_3 = election_data_2016_2.reset_index(drop=True)

# %%
election_data_2016_3.columns=["year", "state", "state_code", "county", "candidate", "party", "candidate_votes", "total_votes"]
election_data_2016_3
# Out:
#       year    state state_code       county        candidate       party  \
# 0     2016  Alabama         AL      Autauga  Hillary Clinton    democrat
# 1     2016  Alabama         AL      Autauga     Donald Trump  republican
# 2     2016  Alabama         AL      Baldwin  Hillary Clinton    democrat
# 3     2016  Alabama         AL      Baldwin     Donald Trump  republican
# 4     2016  Alabama         AL      Barbour  Hillary Clinton    democrat
# ...    ...      ...        ...          ...              ...         ...
# 6301  2016   Alaska         AK  District 38     Donald Trump  republican
# 6302  2016   Alaska         AK  District 39  Hillary Clinton    democrat
# 6303  2016   Alaska         AK  District 39     Donald Trump  republican
# 6304  2016   Alaska         AK  District 40  Hillary Clinton    democrat
# 6305  2016   Alaska         AK  District 40     Donald Trump  republican
#
#       candidate_votes  total_votes
# 0              5936.0        24973
# ...
