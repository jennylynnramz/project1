# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint

# %%
acs2015_census_tract_data = "Resources/acs2015_census_tract_data.csv"
county_data_2015_one= pd.read_csv(acs2015_census_tract_data)
county_data_2015_one
county_data_2015_one['Year'] = 2015


#####not as useful?

# %%
acs2015_county_data = "Resources/acs2015_county_data.csv"
county_data_2015_two= pd.read_csv(acs2015_county_data)
county_data_2015_two['Year'] = 2015
county_data_2015_two
# Out:
#       CensusId        State     County  TotalPop    Men  Women  Hispanic  \
# 0         1001      Alabama    Autauga     55221  26745  28476       2.6
# 1         1003      Alabama    Baldwin    195121  95314  99807       4.5
# 2         1005      Alabama    Barbour     26932  14497  12435       4.6
# 3         1007      Alabama       Bibb     22604  12073  10531       2.2
# 4         1009      Alabama     Blount     57710  28512  29198       8.6
# ...        ...          ...        ...       ...    ...    ...       ...
# 3215     72145  Puerto Rico  Vega Baja     56858  27379  29479      96.4
# 3216     72147  Puerto Rico    Vieques      9130   4585   4545      96.7
# 3217     72149  Puerto Rico   Villalba     24685  12086  12599      99.7
# 3218     72151  Puerto Rico    Yabucoa     36279  17648  18631      99.8
# 3219     72153  Puerto Rico      Yauco     39474  19047  20427      99.5
#
#       White  Black  Native  ...  OtherTransp  WorkAtHome  MeanCommute  \
# ...

# %%
ss07pusa = "../../Downloads/csv_pus/ss07pusa.csv"
something = pd.read_csv(ss07pusa)
something.head()
# Out:
#   RT  SERIALNO  SPORDER  PUMA  ST   ADJUST  PWGTP  AGEP  CIT  COW  ...  \
# 0  P       364        1   200   1  1016787     73    19    1  1.0  ...
# 1  P       447        1   600   1  1016787     87    33    1  3.0  ...
# 2  P       447        2   600   1  1016787     66    25    1  1.0  ...
# 3  P       447        3   600   1  1016787     69     9    1  NaN  ...
# 4  P       447        4   600   1  1016787     70     7    1  NaN  ...
#
#    pwgtp71  pwgtp72  pwgtp73  pwgtp74  pwgtp75  pwgtp76  pwgtp77  pwgtp78  \
# 0       24       76      130      132      122       75       22      128
# 1       29       87      161      160      152       75       85       76
# 2       22       82      111      123      116       56       74       53
# 3       23       71      108      108      113       59       81       66
# 4       22       74      120      108      111       61       80       75
#
#    pwgtp79  pwgtp80
# 0       74       73
# 1       92      172
# 2       65      170
# ...
