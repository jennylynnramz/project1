# %%
#import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint

#file locations
election_data_2000_csv = "Resources/election_data2000.csv"
census_csv = "Resources/population2000-2016ALL.csv"

# %%
#read CSV files
election_data_2000= pd.read_csv(election_data_2000_csv)
census_data= pd.read_csv(census_csv)

# %%
#election data 2000
election_data_2000.head()
# Out:
#    year    state state_po   county       candidate       party  \
# 0  2000  Alabama       AL  Autauga         Al Gore    democrat
# 1  2000  Alabama       AL  Autauga  George W. Bush  republican
# 2  2000  Alabama       AL  Autauga     Ralph Nader       green
# 3  2000  Alabama       AL  Baldwin         Al Gore    democrat
# 4  2000  Alabama       AL  Baldwin  George W. Bush  republican
#
#    candidatevotes  totalvotes
# 0          4942.0       17208
# 1         11993.0       17208
# 2           160.0       17208
# 3         13997.0       56480
# 4         40872.0       56480

# %%
#Census data
census_data.head()
# Out:
#      State   County          Location    2000    2001    2002    2003    2004  \
# 0  Alabama  Autauga  Alabama, Autauga   44021   44889   45909   46800   48366
# 1  Alabama  Baldwin  Alabama, Baldwin  141342  144875  147957  151509  156266
# 2  Alabama  Barbour  Alabama, Barbour   29015   28863   28653   28594   28287
# 3  Alabama     Bibb     Alabama, Bibb   19913   21028   21199   21399   21721
# 4  Alabama   Blount   Alabama, Blount   51107   51845   52551   53457   54124
#
#      2005    2006    2007    2008    2009     2010     2011     2012     2013  \
# 0   49676   51328   52405   53277   54135   54,773   55,227   54,954   54,727
# 1  162183  168121  172404  175827  179406  183,112  186,558  190,145  194,885
# 2   28027   27861   27757   27808   27657   27,327   27,341   27,169   26,937
# 3   22042   22099   22438   22705   22941   22,870   22,745   22,667   22,521
# 4   54624   55485   56240   57055   57341   57,376   57,560   57,580   57,619
#
#       2014     2015     2016
# 0   54,893   54,864   55,243
# 1  199,183  202,939  207,601
# 2   26,755   26,283   25,806
# 3   22,553   22,566   22,586
# 4   57,526   57,526   57,494

# %%
#creat 'Location' column in election data
election_data_2000['Location'] = (election_data_2000.state +", " +election_data_2000.county)
election_data_2000.head()
# Out:
#    year    state state_po   county       candidate       party  \
# 0  2000  Alabama       AL  Autauga         Al Gore    democrat
# 1  2000  Alabama       AL  Autauga  George W. Bush  republican
# 2  2000  Alabama       AL  Autauga     Ralph Nader       green
# 3  2000  Alabama       AL  Baldwin         Al Gore    democrat
# 4  2000  Alabama       AL  Baldwin  George W. Bush  republican
#
#    candidatevotes  totalvotes          Location
# 0          4942.0       17208  Alabama, Autauga
# 1         11993.0       17208  Alabama, Autauga
# 2           160.0       17208  Alabama, Autauga
# 3         13997.0       56480  Alabama, Baldwin
# 4         40872.0       56480  Alabama, Baldwin

# %%
#check political parites
election_data_2000['party'].value_counts()
# Out:
# democrat      3152
# republican    3152
# green         2881
# Name: party, dtype: int64

# %%
#filter out data to only see democrat party so there are less repeats in data when comparing
democrat_2000 = election_data_2000[election_data_2000['party']=="democrat"]
democrat_2000
# Out:
#       year    state state_po       county candidate     party  candidatevotes  \
# 0     2000  Alabama       AL      Autauga   Al Gore  democrat          4942.0
# 3     2000  Alabama       AL      Baldwin   Al Gore  democrat         13997.0
# 6     2000  Alabama       AL      Barbour   Al Gore  democrat          5188.0
# 9     2000  Alabama       AL         Bibb   Al Gore  democrat          2710.0
# 12    2000  Alabama       AL       Blount   Al Gore  democrat          4977.0
# ...    ...      ...      ...          ...       ...       ...             ...
# 9170  2000   Alaska       AK  District 36   Al Gore  democrat          1945.0
# 9173  2000   Alaska       AK  District 37   Al Gore  democrat          1821.0
# 9176  2000   Alaska       AK  District 38   Al Gore  democrat          2015.0
# 9179  2000   Alaska       AK  District 39   Al Gore  democrat          2282.0
# 9182  2000   Alaska       AK  District 40   Al Gore  democrat          1024.0
#
#       totalvotes             Location
# 0          17208     Alabama, Autauga
# 3          56480     Alabama, Baldwin
# 6          10395     Alabama, Barbour
# 9           7101        Alabama, Bibb
# 12         17973      Alabama, Blount
# ...          ...                  ...
# 9170        5577  Alaska, District 36
# 9173        5028  Alaska, District 37
# 9176        4976  Alaska, District 38
# 9179        5188  Alaska, District 39
# 9182        3226  Alaska, District 40
#
# [3152 rows x 9 columns]

# %%
#create separate lists of the location column in each dataframe
csv2 = democrat_2000.Location.tolist()
csv3 = census_data.Location.tolist()

# %%
#find differences between columns
list_difference = []
for item in csv2:
  if item not in csv3:
    list_difference.append(item)

# %%
len(list_difference)
# Out:
# 147

# %%
list_difference2 = []
for item in csv3:
  if item not in csv2:
    list_difference2.append(item)

# %%
len(list_difference2)
# Out:
# 144

# %%
#create new dataframes from each list, name the only column 'location'
election_locations_2000 = pd.DataFrame(csv2, columns = ['location'])
census_locations_2000 = pd.DataFrame(csv3, columns = ['location'])

# %%
election_locations_2000
# Out:
#                  location
# 0        Alabama, Autauga
# 1        Alabama, Baldwin
# 2        Alabama, Barbour
# 3           Alabama, Bibb
# 4         Alabama, Blount
# ...                   ...
# 3147  Alaska, District 36
# 3148  Alaska, District 37
# 3149  Alaska, District 38
# 3150  Alaska, District 39
# 3151  Alaska, District 40
#
# [3152 rows x 1 columns]

# %%
census_locations_2000
# Out:
#                  location
# 0        Alabama, Autauga
# 1        Alabama, Baldwin
# 2        Alabama, Barbour
# 3           Alabama, Bibb
# 4         Alabama, Blount
# ...                   ...
# 3139  Wyoming, Sweetwater
# 3140       Wyoming, Teton
# 3141       Wyoming, Uinta
# 3142    Wyoming, Washakie
# 3143      Wyoming, Weston
#
# [3144 rows x 1 columns]

# %%
result_locations_2000 = pd.merge(election_locations_2000, census_locations_2000, how='inner', left_on="location", right_on="location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
result_locations_2000
# Out:
#                  location
# 0        Alabama, Autauga
# 1        Alabama, Baldwin
# 2        Alabama, Barbour
# 3           Alabama, Bibb
# 4         Alabama, Blount
# ...                   ...
# 3000  Wyoming, Sweetwater
# 3001       Wyoming, Teton
# 3002       Wyoming, Uinta
# 3003    Wyoming, Washakie
# 3004      Wyoming, Weston
#
# [3005 rows x 1 columns]

# %%
#inner merge the location data with the election data to drop the locations not present in both data sets.
election_result_locations_2000 = pd.merge(result_locations_2000, election_data_2000, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
election_result_locations_2000
# Out:
#                location  year    state state_po    county       candidate  \
# 0      Alabama, Autauga  2000  Alabama       AL   Autauga         Al Gore
# 1      Alabama, Autauga  2000  Alabama       AL   Autauga  George W. Bush
# 2      Alabama, Autauga  2000  Alabama       AL   Autauga     Ralph Nader
# 3      Alabama, Baldwin  2000  Alabama       AL   Baldwin         Al Gore
# 4      Alabama, Baldwin  2000  Alabama       AL   Baldwin  George W. Bush
# ...                 ...   ...      ...      ...       ...             ...
# 8770  Wyoming, Washakie  2000  Wyoming       WY  Washakie  George W. Bush
# 8771  Wyoming, Washakie  2000  Wyoming       WY  Washakie     Ralph Nader
# 8772    Wyoming, Weston  2000  Wyoming       WY    Weston         Al Gore
# 8773    Wyoming, Weston  2000  Wyoming       WY    Weston  George W. Bush
# 8774    Wyoming, Weston  2000  Wyoming       WY    Weston     Ralph Nader
#
#            party  candidatevotes  totalvotes           Location
# 0       democrat          4942.0       17208   Alabama, Autauga
# 1     republican         11993.0       17208   Alabama, Autauga
# 2          green           160.0       17208   Alabama, Autauga
# 3       democrat         13997.0       56480   Alabama, Baldwin
# 4     republican         40872.0       56480   Alabama, Baldwin
# ...          ...             ...         ...                ...
# 8770  republican          3138.0        4051  Wyoming, Washakie
# 8771       green            29.0        4051  Wyoming, Washakie
# 8772    democrat           449.0        3060    Wyoming, Weston
# 8773  republican          2521.0        3060    Wyoming, Weston
# 8774       green            26.0        3060    Wyoming, Weston
#
# [8775 rows x 10 columns]

# %%
election_result_locations_2000.count()
# Out:
# location          8775
# year              8775
# state             8775
# state_po          8775
# county            8775
# candidate         8775
# party             8775
# candidatevotes    8775
# totalvotes        8775
# Location          8775
# dtype: int64

# %%
#export to csv
election_result_locations_2000.to_csv(r'Resources/ELECTION_results_FINAL_LOCATIONS_2000.csv', index = False, header=True)

# %%
#merging census data with common locations 

census_result_locations_2000 = pd.merge(result_locations_2000, census_data, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
census_result_locations_2000
# Out:
#                  location    State      County             Location    2000  \
# 0        Alabama, Autauga  Alabama     Autauga     Alabama, Autauga   44021
# 1        Alabama, Baldwin  Alabama     Baldwin     Alabama, Baldwin  141342
# 2        Alabama, Barbour  Alabama     Barbour     Alabama, Barbour   29015
# 3           Alabama, Bibb  Alabama        Bibb        Alabama, Bibb   19913
# 4         Alabama, Blount  Alabama      Blount      Alabama, Blount   51107
# ...                   ...      ...         ...                  ...     ...
# 3000  Wyoming, Sweetwater  Wyoming  Sweetwater  Wyoming, Sweetwater   37552
# 3001       Wyoming, Teton  Wyoming       Teton       Wyoming, Teton   18381
# 3002       Wyoming, Uinta  Wyoming       Uinta       Wyoming, Uinta   19666
# 3003    Wyoming, Washakie  Wyoming    Washakie    Wyoming, Washakie    8252
# 3004      Wyoming, Weston  Wyoming      Weston      Wyoming, Weston    6627
#
#         2001    2002    2003    2004    2005  ...    2007    2008    2009  \
# 0      44889   45909   46800   48366   49676  ...   52405   53277   54135
# 1     144875  147957  151509  156266  162183  ...  172404  175827  179406
# 2      28863   28653   28594   28287   28027  ...   27757   27808   27657
# 3      21028   21199   21399   21721   22042  ...   22438   22705   22941
# 4      51845   52551   53457   54124   54624  ...   56240   57055   57341
# ...      ...     ...     ...     ...     ...  ...     ...     ...     ...
# 3000   36899   37428   37450   38026   38739  ...   41470   42358   44133
# 3001   18653   18837   19066   19467   19632  ...   20472   20988   21232
# 3002   19413   19587   19480   19470   19494  ...   20171   20613   21054
# 3003    8068    7988    7976    7960    8022  ...    8169    8229    8423
# 3004    6487    6578    6610    6646    6594  ...    7033    7133    7266
#
#          2010     2011     2012     2013     2014     2015     2016
# 0      54,773   55,227   54,954   54,727   54,893   54,864   55,243
# 1     183,112  186,558  190,145  194,885  199,183  202,939  207,601
# 2      27,327   27,341   27,169   26,937   26,755   26,283   25,806
# 3      22,870   22,745   22,667   22,521   22,553   22,566   22,586
# 4      57,376   57,560   57,580   57,619   57,526   57,526   57,494
# ...       ...      ...      ...      ...      ...      ...      ...
# 3000   43,574   43,986   45,002   45,157   44,948   44,719   44,222
# 3001   21,296   21,414   21,624   22,315   22,773   23,047   23,234
# 3002   21,089   20,896   20,996   20,951   20,822   20,763   20,682
# 3003    8,530    8,449    8,409    8,413    8,273    8,278    8,165
# 3004    7,198    7,142    7,077    7,136    7,138    7,208    7,220
#
# [3005 rows x 21 columns]

# %%
#export census data to csv
census_result_locations_2000.to_csv(r'Resources/CENSUS_results_FINAL_LOCATIONS_2000.csv', index = False, header=True)
