# %%
#import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint

#file locations
#election file
election_data_2004_csv = "Resources/election_data2004.csv"
#census file
census_data_2004_csv = "Resources/population2000-2016ALL.csv"

# %%
#read CSV files
election_data_2004= pd.read_csv(election_data_2004_csv)
census_data_2004= pd.read_csv(census_data_2004_csv)

# %%
#create column which combines State and County name into one column (Location) for precision when merging
#some county names are repeated in multiple states
election_data_2004['Location'] = (election_data_2004.state +", " +election_data_2004.county)
election_data_2004
# Out:
#       year    state state_code       county       candidate       party  \
# 0     2004  Alabama         AL      Autauga      John Kerry    democrat
# 1     2004  Alabama         AL      Autauga  George W. Bush  republican
# 2     2004  Alabama         AL      Baldwin      John Kerry    democrat
# 3     2004  Alabama         AL      Baldwin  George W. Bush  republican
# 4     2004  Alabama         AL      Barbour      John Kerry    democrat
# ...    ...      ...        ...          ...             ...         ...
# 6303  2004   Alaska         AK  District 38  George W. Bush  republican
# 6304  2004   Alaska         AK  District 39      John Kerry    democrat
# 6305  2004   Alaska         AK  District 39  George W. Bush  republican
# 6306  2004   Alaska         AK  District 40      John Kerry    democrat
# 6307  2004   Alaska         AK  District 40  George W. Bush  republican
#
#       candidate_votes  total_votes             Location
# 0              4758.0        20081     Alabama, Autauga
# 1             15196.0        20081     Alabama, Autauga
# 2             15599.0        69320     Alabama, Baldwin
# 3             52971.0        69320     Alabama, Baldwin
# 4              4832.0        10777     Alabama, Barbour
# ...               ...          ...                  ...
# 6303           2459.0         5075  Alaska, District 38
# 6304           2365.0         5568  Alaska, District 39
# 6305           2881.0         5568  Alaska, District 39
# 6306           2328.0         5788  Alaska, District 40
# 6307           3217.0         5788  Alaska, District 40
#
# [6308 rows x 9 columns]

# %%
#remove the word 'county' from county column in census data to make more location matches, create new column with these cleaner names
census_data_2004.head()
census_data_2004['new_county'] = census_data_2004['County'].str.replace(' County', '')

# %%
#census_data_2004
#confirm individual political parties, no green/other/nan present for this yeaer
election_data_2004['party'].value_counts()
# Out:
# democrat      3154
# republican    3154
# Name: party, dtype: int64

# %%
#filter out data to only see democrat party so there are less repeats in data when comparing
election_data_2004_11 = election_data_2004[election_data_2004['party']=="democrat"]
election_data_2004_11
# Out:
#       year    state state_code       county   candidate     party  \
# 0     2004  Alabama         AL      Autauga  John Kerry  democrat
# 2     2004  Alabama         AL      Baldwin  John Kerry  democrat
# 4     2004  Alabama         AL      Barbour  John Kerry  democrat
# 6     2004  Alabama         AL         Bibb  John Kerry  democrat
# 8     2004  Alabama         AL       Blount  John Kerry  democrat
# ...    ...      ...        ...          ...         ...       ...
# 6298  2004   Alaska         AK  District 36  John Kerry  democrat
# 6300  2004   Alaska         AK  District 37  John Kerry  democrat
# 6302  2004   Alaska         AK  District 38  John Kerry  democrat
# 6304  2004   Alaska         AK  District 39  John Kerry  democrat
# 6306  2004   Alaska         AK  District 40  John Kerry  democrat
#
#       candidate_votes  total_votes             Location
# 0              4758.0        20081     Alabama, Autauga
# 2             15599.0        69320     Alabama, Baldwin
# 4              4832.0        10777     Alabama, Barbour
# 6              2089.0         7600        Alabama, Bibb
# 8              3938.0        21504      Alabama, Blount
# ...               ...          ...                  ...
# 6298           3245.0         9241  Alaska, District 36
# 6300           1970.0         5208  Alaska, District 37
# 6302           2366.0         5075  Alaska, District 38
# 6304           2365.0         5568  Alaska, District 39
# 6306           2328.0         5788  Alaska, District 40
#
# [3154 rows x 9 columns]

# %%
#create separate lists of the location column in each dataframe
csv2 = election_data_2004_11.Location.tolist()
csv3 = census_data_2004.Location.tolist()

# %%
#find differences between columns
list_difference = []
for item in csv2:
  if item not in csv3:
    list_difference.append(item)

# %%
#print(list_difference)

# %%
#find differences in the other direction
list_difference2 = []
for item in csv3:
  if item not in csv2:
    list_difference2.append(item)

# %%
#print(list_difference2)

# %%
#count the total length of each difference list
len(list_difference2)
# Out:
# 143

# %%
#count the total length of each difference list
len(list_difference)
# Out:
# 148

# %%
#create new dataframes from each list, name the only column 'location'
election_locations_2004 = pd.DataFrame(csv2, columns = ['location'])
census_locations_2004 = pd.DataFrame(csv3, columns = ['location'])

# %%
#census_locations_2004

# %%
#merging election data with common locations to create shorter, but matching data
result_locations_2004 = pd.merge(election_locations_2004, census_locations_2004, how='inner', left_on="location", right_on="location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
#view resuts, 3006 rows.
result_locations_2004.location.value_counts()
# Out:
# Virginia, Bedford          2
# Virginia, Franklin         2
# Virginia, Roanoke          2
# Virginia, Fairfax          2
# Virginia, Richmond         2
#                           ..
# North Carolina, Watauga    1
# Texas, Duval               1
# North Carolina, Durham     1
# Arkansas, Pulaski          1
# Nebraska, Wheeler          1
# Name: location, Length: 3001, dtype: int64

# %%
election_result_locations_2004 = pd.merge(result_locations_2004, election_data_2004, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
#view results
election_result_locations_2004

election_result_locations_2004_drop = election_result_locations_2004.drop(["location"], axis=1)

# %%
#resuults of ELECTION DATA to csv
election_result_locations_2004_drop.to_csv(r'Resources/ELECTION_results_FINAL_LOCATIONS_2004.csv', index = False, header=True)

# %%
#merging census data with common locations 

census_result_locations_2004 = pd.merge(result_locations_2004, census_data_2004, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
census_result_locations_2004

census_result_locations_2004_drop = census_result_locations_2004.drop(['location', '2000', '2001', '2002', '2003', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012','2013', '2014', '2015', '2016'], axis=1)

# %%
#CENSUS data to CSV
census_result_locations_2004_drop.to_csv(r'Resources/CENSUS_results_FINAL_LOCATIONS_2004.csv', index = False, header=True)

# %%
#merging census data with common locations 

census_AND_election_2004_1 = pd.merge(election_result_locations_2004_drop, census_result_locations_2004_drop, how='inner', left_on="Location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
census_AND_election_2004_1
# Out:
#       year    state state_code    county       candidate       party  \
# 0     2004  Alabama         AL   Autauga      John Kerry    democrat
# 1     2004  Alabama         AL   Autauga  George W. Bush  republican
# 2     2004  Alabama         AL   Baldwin      John Kerry    democrat
# 3     2004  Alabama         AL   Baldwin  George W. Bush  republican
# 4     2004  Alabama         AL   Barbour      John Kerry    democrat
# ...    ...      ...        ...       ...             ...         ...
# 6067  2004  Wyoming         WY     Uinta  George W. Bush  republican
# 6068  2004  Wyoming         WY  Washakie      John Kerry    democrat
# 6069  2004  Wyoming         WY  Washakie  George W. Bush  republican
# 6070  2004  Wyoming         WY    Weston      John Kerry    democrat
# 6071  2004  Wyoming         WY    Weston  George W. Bush  republican
#
#       candidate_votes  total_votes           Location    State    County  \
# 0              4758.0        20081   Alabama, Autauga  Alabama   Autauga
# 1             15196.0        20081   Alabama, Autauga  Alabama   Autauga
# 2             15599.0        69320   Alabama, Baldwin  Alabama   Baldwin
# 3             52971.0        69320   Alabama, Baldwin  Alabama   Baldwin
# 4              4832.0        10777   Alabama, Barbour  Alabama   Barbour
# ...               ...          ...                ...      ...       ...
# 6067           6081.0         8081     Wyoming, Uinta  Wyoming     Uinta
# 6068            855.0         4114  Wyoming, Washakie  Wyoming  Washakie
# 6069           3200.0         4114  Wyoming, Washakie  Wyoming  Washakie
# 6070            580.0         3392    Wyoming, Weston  Wyoming    Weston
# 6071           2739.0         3392    Wyoming, Weston  Wyoming    Weston
#
#         2004 new_county
# 0      48366    Autauga
# 1      48366    Autauga
# 2     156266    Baldwin
# 3     156266    Baldwin
# 4      28287    Barbour
# ...      ...        ...
# 6067   19470      Uinta
# 6068    7960   Washakie
# 6069    7960   Washakie
# 6070    6646     Weston
# 6071    6646     Weston
#
# [6072 rows x 13 columns]

# %%
census_AND_election_2004_drop = census_AND_election_2004_1.drop(['state', 'county', 'new_county'], axis=1)

# %%
census_AND_election_2004_drop_rename = census_AND_election_2004_drop.rename(columns={"year":"Year", "state_code":"State_Code", "candidate":"Candidate", "party":"Party", "candidate_votes":"Candidate_Votes", "total_votes":"Total_Votes", "2004":"County_Pop_2004"
})

# %%
census_AND_election_2004_reorder = census_AND_election_2004_drop_rename[["County", "State", "State_Code", "Location", "Year", "Party", "Candidate", "Candidate_Votes", "Total_Votes", "County_Pop_2004"]]

# %%
census_AND_election_2004_reorder
# Out:
#         County    State State_Code           Location  Year       Party  \
# 0      Autauga  Alabama         AL   Alabama, Autauga  2004    democrat
# 1      Autauga  Alabama         AL   Alabama, Autauga  2004  republican
# 2      Baldwin  Alabama         AL   Alabama, Baldwin  2004    democrat
# 3      Baldwin  Alabama         AL   Alabama, Baldwin  2004  republican
# 4      Barbour  Alabama         AL   Alabama, Barbour  2004    democrat
# ...        ...      ...        ...                ...   ...         ...
# 6067     Uinta  Wyoming         WY     Wyoming, Uinta  2004  republican
# 6068  Washakie  Wyoming         WY  Wyoming, Washakie  2004    democrat
# 6069  Washakie  Wyoming         WY  Wyoming, Washakie  2004  republican
# 6070    Weston  Wyoming         WY    Wyoming, Weston  2004    democrat
# 6071    Weston  Wyoming         WY    Wyoming, Weston  2004  republican
#
#            Candidate  Candidate_Votes  Total_Votes  County_Pop_2004
# 0         John Kerry           4758.0        20081            48366
# 1     George W. Bush          15196.0        20081            48366
# 2         John Kerry          15599.0        69320           156266
# 3     George W. Bush          52971.0        69320           156266
# 4         John Kerry           4832.0        10777            28287
# ...              ...              ...          ...              ...
# 6067  George W. Bush           6081.0         8081            19470
# 6068      John Kerry            855.0         4114             7960
# 6069  George W. Bush           3200.0         4114             7960
# 6070      John Kerry            580.0         3392             6646
# 6071  George W. Bush           2739.0         3392             6646
#
# [6072 rows x 10 columns]

# %%
republican_2004 = census_AND_election_2004_reorder.loc[census_AND_election_2004_reorder["Party"] == 'republican']
republican_2004_1 = pd.DataFrame(republican_2004)

# %%
republican_2004_1.sort_values("Location", inplace = True)

# %%
republican_2004_1.drop_duplicates(subset ="Location", 
                     keep = False, inplace = True)

# %%
republican_2004_1
# Out:
#       Total_Votes  2004_republican_votes             Location
# 1           20081                15196.0     Alabama, Autauga
# 3           69320                52971.0     Alabama, Baldwin
# 5           10777                 5899.0     Alabama, Barbour
# 7            7600                 5472.0        Alabama, Bibb
# 9           21504                17386.0      Alabama, Blount
# ...           ...                    ...                  ...
# 6063        16272                10653.0  Wyoming, Sweetwater
# 6065        11359                 5124.0       Wyoming, Teton
# 6067         8081                 6081.0       Wyoming, Uinta
# 6069         4114                 3200.0    Wyoming, Washakie
# 6071         3392                 2739.0      Wyoming, Weston
#
# [3036 rows x 3 columns]

# %%
democrat_2004 = census_AND_election_2004_reorder.loc[census_AND_election_2004_reorder["Party"] == 'democrat']
democrat_2004_1 = pd.DataFrame(democrat_2004)

# %%
democrat_2004_1.sort_values("Location", inplace = True)

# %%
democrat_2004_1.drop_duplicates(subset ="Location", 
                     keep = False, inplace = True)
democrat_2004_1
# Out:
#           County    State State_Code             Location  Year     Party  \
# 0        Autauga  Alabama         AL     Alabama, Autauga  2004  democrat
# 2        Baldwin  Alabama         AL     Alabama, Baldwin  2004  democrat
# 4        Barbour  Alabama         AL     Alabama, Barbour  2004  democrat
# 6           Bibb  Alabama         AL        Alabama, Bibb  2004  democrat
# 8         Blount  Alabama         AL      Alabama, Blount  2004  democrat
# ...          ...      ...        ...                  ...   ...       ...
# 6062  Sweetwater  Wyoming         WY  Wyoming, Sweetwater  2004  democrat
# 6064       Teton  Wyoming         WY       Wyoming, Teton  2004  democrat
# 6066       Uinta  Wyoming         WY       Wyoming, Uinta  2004  democrat
# 6068    Washakie  Wyoming         WY    Wyoming, Washakie  2004  democrat
# 6070      Weston  Wyoming         WY      Wyoming, Weston  2004  democrat
#
#        Candidate  Candidate_Votes  Total_Votes  County_Pop_2004
# 0     John Kerry           4758.0        20081            48366
# 2     John Kerry          15599.0        69320           156266
# 4     John Kerry           4832.0        10777            28287
# 6     John Kerry           2089.0         7600            21721
# 8     John Kerry           3938.0        21504            54124
# ...          ...              ...          ...              ...
# 6062  John Kerry           5208.0        16272            38026
# 6064  John Kerry           5972.0        11359            19467
# 6066  John Kerry           1815.0         8081            19470
# 6068  John Kerry            855.0         4114             7960
# 6070  John Kerry            580.0         3392             6646
#
# [2996 rows x 10 columns]

# %%
democrat_2004_1
# Out:
#           County    State State_Code             Location  Year     Party  \
# 0        Autauga  Alabama         AL     Alabama, Autauga  2004  democrat
# 2        Baldwin  Alabama         AL     Alabama, Baldwin  2004  democrat
# 4        Barbour  Alabama         AL     Alabama, Barbour  2004  democrat
# 6           Bibb  Alabama         AL        Alabama, Bibb  2004  democrat
# 8         Blount  Alabama         AL      Alabama, Blount  2004  democrat
# ...          ...      ...        ...                  ...   ...       ...
# 6062  Sweetwater  Wyoming         WY  Wyoming, Sweetwater  2004  democrat
# 6064       Teton  Wyoming         WY       Wyoming, Teton  2004  democrat
# 6066       Uinta  Wyoming         WY       Wyoming, Uinta  2004  democrat
# 6068    Washakie  Wyoming         WY    Wyoming, Washakie  2004  democrat
# 6070      Weston  Wyoming         WY      Wyoming, Weston  2004  democrat
#
#        Candidate  Candidate_Votes  Total_Votes  County_Pop_2004
# 0     John Kerry           4758.0        20081            48366
# 2     John Kerry          15599.0        69320           156266
# 4     John Kerry           4832.0        10777            28287
# 6     John Kerry           2089.0         7600            21721
# 8     John Kerry           3938.0        21504            54124
# ...          ...              ...          ...              ...
# 6062  John Kerry           5208.0        16272            38026
# 6064  John Kerry           5972.0        11359            19467
# 6066  John Kerry           1815.0         8081            19470
# 6068  John Kerry            855.0         4114             7960
# 6070  John Kerry            580.0         3392             6646
#
# [3036 rows x 10 columns]

# %%
# collecting required columns...
republican_2004_2 = republican_2004_1[['Total_Votes', '2004_republican_votes', 'Location']]
republican_2004_2.columns = ['Total_Votes', '2004_republican_votes', 'Location']
republican_2004_2
# Out:
#       Total_Votes  2004_republican_votes             Location
# 1           20081                15196.0     Alabama, Autauga
# 3           69320                52971.0     Alabama, Baldwin
# 5           10777                 5899.0     Alabama, Barbour
# 7            7600                 5472.0        Alabama, Bibb
# 9           21504                17386.0      Alabama, Blount
# ...           ...                    ...                  ...
# 6063        16272                10653.0  Wyoming, Sweetwater
# 6065        11359                 5124.0       Wyoming, Teton
# 6067         8081                 6081.0       Wyoming, Uinta
# 6069         4114                 3200.0    Wyoming, Washakie
# 6071         3392                 2739.0      Wyoming, Weston
#
# [3036 rows x 3 columns]

# %%
democrat_2004_2 = democrat_2004_1[['Total_Votes', 'Candidate_Votes', 'Location']]
democrat_2004_2.columns = ['Total_Votes', '2004_democrat_votes', 'Location']
democrat_2004_2.head()
# Out:
#    Total_Votes  2004_democrat_votes          Location
# 0        20081               4758.0  Alabama, Autauga
# 2        69320              15599.0  Alabama, Baldwin
# 4        10777               4832.0  Alabama, Barbour
# 6         7600               2089.0     Alabama, Bibb
# 8        21504               3938.0   Alabama, Blount

# %%
election_parties_2004 = pd.merge(republican_2004_2,democrat_2004_2, on='Location')
election_parties_2004
election_parties_2004 = election_parties_2004[['Location','Total_Votes_x','2004_republican_votes','2004_democrat_votes']]
election_parties_2004.columns = ['Location','Total_Votes_2004','2004_republican_votes','2004_democrat_votes']
election_parties_2004
# Out:
#                  Location  Total_Votes_2004  2004_republican_votes  \
# 0        Alabama, Autauga             20081                15196.0
# 1        Alabama, Baldwin             69320                52971.0
# 2        Alabama, Barbour             10777                 5899.0
# 3           Alabama, Bibb              7600                 5472.0
# 4         Alabama, Blount             21504                17386.0
# ...                   ...               ...                    ...
# 3311  Wyoming, Sweetwater             16272                10653.0
# 3312       Wyoming, Teton             11359                 5124.0
# 3313       Wyoming, Uinta              8081                 6081.0
# 3314    Wyoming, Washakie              4114                 3200.0
# 3315      Wyoming, Weston              3392                 2739.0
#
#       2004_democrat_votes
# 0                  4758.0
# 1                 15599.0
# 2                  4832.0
# 3                  2089.0
# 4                  3938.0
# ...                   ...
# 3311               5208.0
# 3312               5972.0
# 3313               1815.0
# 3314                855.0
# 3315                580.0
#
# [3316 rows x 4 columns]

# %%
election_parties_2004.to_csv(r'Resources/FOR_JINHO_2004.csv', index = False, header=True)

# %%
election_census_parties_2004= pd.merge(election_parties_2004, census_AND_election_2004_reorder, on='Location')
election_census_parties_2004
# Out:
#                Location  Total_Votes_2004  2004_republican_votes  \
# 0      Alabama, Autauga             20081                15196.0
# 1      Alabama, Autauga             20081                15196.0
# 2      Alabama, Baldwin             69320                52971.0
# 3      Alabama, Baldwin             69320                52971.0
# 4      Alabama, Barbour             10777                 5899.0
# ...                 ...               ...                    ...
# 5987     Wyoming, Uinta              8081                 6081.0
# 5988  Wyoming, Washakie              4114                 3200.0
# 5989  Wyoming, Washakie              4114                 3200.0
# 5990    Wyoming, Weston              3392                 2739.0
# 5991    Wyoming, Weston              3392                 2739.0
#
#       2004_democrat_votes    County    State State_Code  Year       Party  \
# 0                  4758.0   Autauga  Alabama         AL  2004    democrat
# 1                  4758.0   Autauga  Alabama         AL  2004  republican
# 2                 15599.0   Baldwin  Alabama         AL  2004    democrat
# 3                 15599.0   Baldwin  Alabama         AL  2004  republican
# 4                  4832.0   Barbour  Alabama         AL  2004    democrat
# ...                   ...       ...      ...        ...   ...         ...
# 5987               1815.0     Uinta  Wyoming         WY  2004  republican
# 5988                855.0  Washakie  Wyoming         WY  2004    democrat
# 5989                855.0  Washakie  Wyoming         WY  2004  republican
# 5990                580.0    Weston  Wyoming         WY  2004    democrat
# 5991                580.0    Weston  Wyoming         WY  2004  republican
#
#            Candidate  Candidate_Votes  Total_Votes  County_Pop_2004
# 0         John Kerry           4758.0        20081            48366
# 1     George W. Bush          15196.0        20081            48366
# 2         John Kerry          15599.0        69320           156266
# 3     George W. Bush          52971.0        69320           156266
# 4         John Kerry           4832.0        10777            28287
# ...              ...              ...          ...              ...
# 5987  George W. Bush           6081.0         8081            19470
# 5988      John Kerry            855.0         4114             7960
# 5989  George W. Bush           3200.0         4114             7960
# 5990      John Kerry            580.0         3392             6646
# 5991  George W. Bush           2739.0         3392             6646
#
# [5992 rows x 13 columns]

# %%
election_census_parties_2004_drop = election_census_parties_2004.drop(["Total_Votes_2004", "2004_republican_votes", "2004_democrat_votes", "Year", "Candidate_Votes"], axis=1)

# %%
election_census_parties_2004_drop.to_csv(r'Resources/Analysis Files/2004/CENSUS_and_POPULATION_FINAL_2004.csv', index = False, header=True)
