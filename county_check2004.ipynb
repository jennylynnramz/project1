# %%
#import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint

#file locations
#election file
election_data_2004_csv = "Resources/election_data2004.csv"
#census file
census_data_2004_csv = "Resources/population2000-2016ALL.csv"

# %%
#read CSV files
election_data_2004= pd.read_csv(election_data_2004_csv)
census_data_2004= pd.read_csv(census_data_2004_csv)

# %%
#create column which combines State and County name into one column (Location) for precision when merging
#some county names are repeated in multiple states
election_data_2004['Location'] = (election_data_2004.state +", " +election_data_2004.county)
election_data_2004
# Out:
#       year    state state_code       county       candidate       party  \
# 0     2004  Alabama         AL      Autauga      John Kerry    democrat
# 1     2004  Alabama         AL      Autauga  George W. Bush  republican
# 2     2004  Alabama         AL      Baldwin      John Kerry    democrat
# 3     2004  Alabama         AL      Baldwin  George W. Bush  republican
# 4     2004  Alabama         AL      Barbour      John Kerry    democrat
# ...    ...      ...        ...          ...             ...         ...
# 6303  2004   Alaska         AK  District 38  George W. Bush  republican
# 6304  2004   Alaska         AK  District 39      John Kerry    democrat
# 6305  2004   Alaska         AK  District 39  George W. Bush  republican
# 6306  2004   Alaska         AK  District 40      John Kerry    democrat
# 6307  2004   Alaska         AK  District 40  George W. Bush  republican
#
#       candidate_votes  total_votes             Location
# 0              4758.0        20081     Alabama, Autauga
# 1             15196.0        20081     Alabama, Autauga
# 2             15599.0        69320     Alabama, Baldwin
# 3             52971.0        69320     Alabama, Baldwin
# 4              4832.0        10777     Alabama, Barbour
# ...               ...          ...                  ...
# 6303           2459.0         5075  Alaska, District 38
# 6304           2365.0         5568  Alaska, District 39
# 6305           2881.0         5568  Alaska, District 39
# 6306           2328.0         5788  Alaska, District 40
# 6307           3217.0         5788  Alaska, District 40
#
# [6308 rows x 9 columns]

# %%
#remove the word 'county' from county column in census data to make more location matches, create new column with these cleaner names
census_data_2004.head()
census_data_2004['new_county'] = census_data_2004['County'].str.replace(' County', '')

# %%
#census_data_2004
#confirm individual political parties, no green/other/nan present for this yeaer
election_data_2004['party'].value_counts()
# Out:
# democrat      3154
# republican    3154
# Name: party, dtype: int64

# %%
#filter out data to only see democrat party so there are less repeats in data when comparing
election_data_2004_11 = election_data_2004[election_data_2004['party']=="democrat"]
election_data_2004_11
# Out:
#       year    state state_code       county   candidate     party  \
# 0     2004  Alabama         AL      Autauga  John Kerry  democrat
# 2     2004  Alabama         AL      Baldwin  John Kerry  democrat
# 4     2004  Alabama         AL      Barbour  John Kerry  democrat
# 6     2004  Alabama         AL         Bibb  John Kerry  democrat
# 8     2004  Alabama         AL       Blount  John Kerry  democrat
# ...    ...      ...        ...          ...         ...       ...
# 6298  2004   Alaska         AK  District 36  John Kerry  democrat
# 6300  2004   Alaska         AK  District 37  John Kerry  democrat
# 6302  2004   Alaska         AK  District 38  John Kerry  democrat
# 6304  2004   Alaska         AK  District 39  John Kerry  democrat
# 6306  2004   Alaska         AK  District 40  John Kerry  democrat
#
#       candidate_votes  total_votes             Location
# 0              4758.0        20081     Alabama, Autauga
# 2             15599.0        69320     Alabama, Baldwin
# 4              4832.0        10777     Alabama, Barbour
# 6              2089.0         7600        Alabama, Bibb
# 8              3938.0        21504      Alabama, Blount
# ...               ...          ...                  ...
# 6298           3245.0         9241  Alaska, District 36
# 6300           1970.0         5208  Alaska, District 37
# 6302           2366.0         5075  Alaska, District 38
# 6304           2365.0         5568  Alaska, District 39
# 6306           2328.0         5788  Alaska, District 40
#
# [3154 rows x 9 columns]

# %%
#create separate lists of the location column in each dataframe
csv2 = election_data_2004_11.Location.tolist()
csv3 = census_data_2004.Location.tolist()

# %%
#find differences between columns
list_difference = []
for item in csv2:
  if item not in csv3:
    list_difference.append(item)

# %%
#print(list_difference)

# %%
#find differences in the other direction
list_difference2 = []
for item in csv3:
  if item not in csv2:
    list_difference2.append(item)

# %%
#print(list_difference2)

# %%
#count the total length of each difference list
len(list_difference2)
# Out:
# 143

# %%
#count the total length of each difference list
len(list_difference)
# Out:
# 148

# %%
#create new dataframes from each list, name the only column 'location'
election_locations_2004 = pd.DataFrame(csv2, columns = ['location'])
census_locations_2004 = pd.DataFrame(csv3, columns = ['location'])

# %%
#census_locations_2004

# %%
#merging election data with common locations to create shorter, but matching data
result_locations_2004 = pd.merge(election_locations_2004, census_locations_2004, how='inner', left_on="location", right_on="location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
#view resuts, 3006 rows.
result_locations_2004
# Out:
#                  location
# 0        Alabama, Autauga
# 1        Alabama, Baldwin
# 2        Alabama, Barbour
# 3           Alabama, Bibb
# 4         Alabama, Blount
# ...                   ...
# 3001  Wyoming, Sweetwater
# 3002       Wyoming, Teton
# 3003       Wyoming, Uinta
# 3004    Wyoming, Washakie
# 3005      Wyoming, Weston
#
# [3006 rows x 1 columns]

# %%
election_result_locations_2004 = pd.merge(result_locations_2004, election_data_2004, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
#view results
election_result_locations_2004
# Out:
#                location  year    state state_code    county       candidate  \
# 0      Alabama, Autauga  2004  Alabama         AL   Autauga      John Kerry
# 1      Alabama, Autauga  2004  Alabama         AL   Autauga  George W. Bush
# 2      Alabama, Baldwin  2004  Alabama         AL   Baldwin      John Kerry
# 3      Alabama, Baldwin  2004  Alabama         AL   Baldwin  George W. Bush
# 4      Alabama, Barbour  2004  Alabama         AL   Barbour      John Kerry
# ...                 ...   ...      ...        ...       ...             ...
# 6027     Wyoming, Uinta  2004  Wyoming         WY     Uinta  George W. Bush
# 6028  Wyoming, Washakie  2004  Wyoming         WY  Washakie      John Kerry
# 6029  Wyoming, Washakie  2004  Wyoming         WY  Washakie  George W. Bush
# 6030    Wyoming, Weston  2004  Wyoming         WY    Weston      John Kerry
# 6031    Wyoming, Weston  2004  Wyoming         WY    Weston  George W. Bush
#
#            party  candidate_votes  total_votes           Location
# 0       democrat           4758.0        20081   Alabama, Autauga
# 1     republican          15196.0        20081   Alabama, Autauga
# 2       democrat          15599.0        69320   Alabama, Baldwin
# 3     republican          52971.0        69320   Alabama, Baldwin
# 4       democrat           4832.0        10777   Alabama, Barbour
# ...          ...              ...          ...                ...
# 6027  republican           6081.0         8081     Wyoming, Uinta
# 6028    democrat            855.0         4114  Wyoming, Washakie
# 6029  republican           3200.0         4114  Wyoming, Washakie
# 6030    democrat            580.0         3392    Wyoming, Weston
# 6031  republican           2739.0         3392    Wyoming, Weston
#
# [6032 rows x 10 columns]

# %%
#resuults of ELECTION DATA to csv
election_result_locations_2004.to_csv(r'Resources/ELECTION_results_FINAL_LOCATIONS_2004.csv', index = False, header=True)

# %%
#merging census data with common locations 

census_result_locations_2004 = pd.merge(result_locations_2004, census_data_2004, how='inner', left_on="location", right_on="Location",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
census_result_locations_2004
# Out:
#                  location    State      County             Location    2000  \
# 0        Alabama, Autauga  Alabama     Autauga     Alabama, Autauga   44021
# 1        Alabama, Baldwin  Alabama     Baldwin     Alabama, Baldwin  141342
# 2        Alabama, Barbour  Alabama     Barbour     Alabama, Barbour   29015
# 3           Alabama, Bibb  Alabama        Bibb        Alabama, Bibb   19913
# 4         Alabama, Blount  Alabama      Blount      Alabama, Blount   51107
# ...                   ...      ...         ...                  ...     ...
# 3001  Wyoming, Sweetwater  Wyoming  Sweetwater  Wyoming, Sweetwater   37552
# 3002       Wyoming, Teton  Wyoming       Teton       Wyoming, Teton   18381
# 3003       Wyoming, Uinta  Wyoming       Uinta       Wyoming, Uinta   19666
# 3004    Wyoming, Washakie  Wyoming    Washakie    Wyoming, Washakie    8252
# 3005      Wyoming, Weston  Wyoming      Weston      Wyoming, Weston    6627
#
#         2001    2002    2003    2004    2005  ...    2008    2009     2010  \
# 0      44889   45909   46800   48366   49676  ...   53277   54135   54,773
# 1     144875  147957  151509  156266  162183  ...  175827  179406  183,112
# 2      28863   28653   28594   28287   28027  ...   27808   27657   27,327
# 3      21028   21199   21399   21721   22042  ...   22705   22941   22,870
# 4      51845   52551   53457   54124   54624  ...   57055   57341   57,376
# ...      ...     ...     ...     ...     ...  ...     ...     ...      ...
# 3001   36899   37428   37450   38026   38739  ...   42358   44133   43,574
# 3002   18653   18837   19066   19467   19632  ...   20988   21232   21,296
# 3003   19413   19587   19480   19470   19494  ...   20613   21054   21,089
# 3004    8068    7988    7976    7960    8022  ...    8229    8423    8,530
# 3005    6487    6578    6610    6646    6594  ...    7133    7266    7,198
#
#          2011     2012     2013     2014     2015     2016  new_county
# 0      55,227   54,954   54,727   54,893   54,864   55,243     Autauga
# 1     186,558  190,145  194,885  199,183  202,939  207,601     Baldwin
# 2      27,341   27,169   26,937   26,755   26,283   25,806     Barbour
# 3      22,745   22,667   22,521   22,553   22,566   22,586        Bibb
# 4      57,560   57,580   57,619   57,526   57,526   57,494      Blount
# ...       ...      ...      ...      ...      ...      ...         ...
# 3001   43,986   45,002   45,157   44,948   44,719   44,222  Sweetwater
# 3002   21,414   21,624   22,315   22,773   23,047   23,234       Teton
# 3003   20,896   20,996   20,951   20,822   20,763   20,682       Uinta
# 3004    8,449    8,409    8,413    8,273    8,278    8,165    Washakie
# 3005    7,142    7,077    7,136    7,138    7,208    7,220      Weston
#
# [3006 rows x 22 columns]

# %%
#CENSUS data to CSV
census_result_locations_2004.to_csv(r'Resources/CENSUS_results_FINAL_LOCATIONS_2004.csv', index = False, header=True)
