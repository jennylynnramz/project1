# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
from scipy.stats import linregress
from pprint import pprint


countyPopEst2010_2019_csv = "Resources/countyPopEst2010_2019(edited).csv"


####Annual Estimates of the Resident Population for Counties in the United States: April 1, 2010 to July 1, 2019 (CO-EST2019-ANNRES)###

# %%
countyPopEst2010_2019= pd.read_csv(countyPopEst2010_2019_csv)
#countyPopEst2010_2019

# %%
countyPop2010_2019 = countyPopEst2010_2019.drop(columns=['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'])

# %%
countyPop2010_2019.columns=["County", "State", "Census", "Estimates Base", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]

# %%
countyPop2010_2016 = countyPop2010_2019.drop(columns=['2017', '2018', '2019', 'Census', 'Estimates Base'])

# %%
countyPop2010_2016.reset_index(drop=True)
# Out:
#               County                                              State  \
# 0                NaN                                                NaN
# 1     Autauga County                                            Alabama
# 2     Baldwin County                                            Alabama
# 3     Barbour County                                            Alabama
# 4        Bibb County                                            Alabama
# ...              ...                                                ...
# 3144             NaN  Note: The 6,222 people in Bedford city, Virgin...
# 3145             NaN                                Suggested Citation:
# 3146             NaN  Annual Estimates of the Resident Population fo...
# 3147             NaN    Source: U.S. Census Bureau, Population Division
# 3148             NaN                           Release Date: March 2020
#
#          2010     2011     2012     2013     2014     2015     2016
# ...

# %%
countyPop2010_2016_dropped = countyPop2010_2016.dropna()
countyPop2010_2016_dropped
# Out:
#                  County     State     2010     2011     2012     2013  \
# 1        Autauga County   Alabama   54,773   55,227   54,954   54,727
# 2        Baldwin County   Alabama  183,112  186,558  190,145  194,885
# 3        Barbour County   Alabama   27,327   27,341   27,169   26,937
# 4           Bibb County   Alabama   22,870   22,745   22,667   22,521
# 5         Blount County   Alabama   57,376   57,560   57,580   57,619
# ...                 ...       ...      ...      ...      ...      ...
# 3138  Sweetwater County   Wyoming   43,574   43,986   45,002   45,157
# 3139       Teton County   Wyoming   21,296   21,414   21,624   22,315
# 3140       Uinta County   Wyoming   21,089   20,896   20,996   20,951
# 3141    Washakie County   Wyoming    8,530    8,449    8,409    8,413
# 3142      Weston County   Wyoming    7,198    7,142    7,077    7,136
#
#          2014     2015     2016
# 1      54,893   54,864   55,243
# 2     199,183  202,939  207,601
# ...

# %%
countyPop2010_2016_dropped2 = pd.DataFrame(countyPop2010_2016_dropped)

# %%
countyPop2010_2016_dropped2['County'] = countyPop2010_2016_dropped2['County'].str.replace(' County', '')

# %%
countyPop2010_2016_dropped2
# Out:
#           County     State     2010     2011     2012     2013     2014  \
# 1        Autauga   Alabama   54,773   55,227   54,954   54,727   54,893
# 2        Baldwin   Alabama  183,112  186,558  190,145  194,885  199,183
# 3        Barbour   Alabama   27,327   27,341   27,169   26,937   26,755
# 4           Bibb   Alabama   22,870   22,745   22,667   22,521   22,553
# 5         Blount   Alabama   57,376   57,560   57,580   57,619   57,526
# ...          ...       ...      ...      ...      ...      ...      ...
# 3138  Sweetwater   Wyoming   43,574   43,986   45,002   45,157   44,948
# 3139       Teton   Wyoming   21,296   21,414   21,624   22,315   22,773
# 3140       Uinta   Wyoming   21,089   20,896   20,996   20,951   20,822
# 3141    Washakie   Wyoming    8,530    8,449    8,409    8,413    8,273
# 3142      Weston   Wyoming    7,198    7,142    7,077    7,136    7,138
#
#          2015     2016
# 1      54,864   55,243
# 2     202,939  207,601
# 3      26,283   25,806
# ...

# %%
countyPop2010_2016_dropped2['State'] = countyPop2010_2016_dropped2['State'].str.strip()
countyPop2010_2016_dropped2['County'] = countyPop2010_2016_dropped2['County'].str.strip()

# %%
countyPop2010_2016_dropped2.to_csv (r'Resources/countyPop2010_2016_CLEAN.csv', index = False, header=True)
